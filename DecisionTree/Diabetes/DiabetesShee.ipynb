# %%
    import pandas as pd
    import matplotlib.pyplot as plt
    # %matplotlib inline

    from sklearn.tree import DecisionTreeClassifier
    from sklearn.linear_model import LinearRegression

    from sklearn.model_selection import train_test_split
    from sklearn.metrics import mean_squared_error
    from sklearn.datasets import load_iris

# %%
df=pd.read_csv("diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X=df.drop(["Outcome"],axis=1)
y=df["Outcome"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=17)
print("The diamension of X_train is{}".format(X_train.shape))
print("The diamension of X_test is{}".format(X_test.shape))
# Out:
# The diamension of X_train is(537, 8)
# The diamension of X_test is(231, 8)

# %%
dt_classifier=DecisionTreeClassifier()
dt_classifier.fit(X_train,y_train)

score=dt_classifier.score(X_train,y_train)
print("R Squared Train : ",score)

score=dt_classifier.score(X_test,y_test)
print("R Squared Test : ",score)

y_pred=dt_classifier.predict(X_test)

mse=mean_squared_error(y_test,y_pred)
print("MSE:",mse)
print("RMSE:",mse**(1/2.0))
# Out:
# R Squared Train :  1.0
# R Squared Test :  0.7229437229437229
# MSE: 0.27705627705627706
# RMSE: 0.5263613559678152

# %%
from sklearn import tree
#from sklearn import plottree
plt.figure(figsize=(15,10))
tree.plot_tree(dt_classifier,filled=True)
# Out:
# [Text(0.5536212270341208, 0.96875, 'X[1] <= 143.5\ngini = 0.454\nsamples = 537\nvalue = [350, 187]'),
#  Text(0.2673474409448819, 0.90625, 'X[7] <= 28.5\ngini = 0.366\nsamples = 419\nvalue = [318, 101]'),
#  Text(0.18799212598425197, 0.84375, 'X[5] <= 45.4\ngini = 0.196\nsamples = 218\nvalue = [194, 24]'),
#  Text(0.15026246719160105, 0.78125, 'X[6] <= 0.898\ngini = 0.177\nsamples = 214\nvalue = [193, 21]'),
#  Text(0.1062992125984252, 0.71875, 'X[0] <= 7.5\ngini = 0.139\nsamples = 200\nvalue = [185, 15]'),
#  Text(0.09580052493438321, 0.65625, 'X[1] <= 131.5\ngini = 0.131\nsamples = 199\nvalue = [185, 14]'),
#  Text(0.049868766404199474, 0.59375, 'X[5] <= 30.9\ngini = 0.102\nsamples = 185\nvalue = [175, 10]'),
#  Text(0.02099737532808399, 0.53125, 'X[6] <= 0.672\ngini = 0.02\nsamples = 101\nvalue = [100, 1]'),
#  Text(0.010498687664041995, 0.46875, 'gini = 0.0\nsamples = 92\nvalue = [92, 0]'),
#  Text(0.031496062992125984, 0.46875, 'X[6] <= 0.685\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.02099737532808399, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04199475065616798, 0.40625, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.07874015748031496, 0.53125, 'X[5] <= 31.3\ngini = 0.191\nsamples = 84\nvalue = [75, 9]'),
#  Text(0.06824146981627296, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08923884514435695, 0.46875, 'X[4] <= 38.0\ngini = 0.174\nsamples = 83\nvalue = [75, 8]'),
#  Text(0.06299212598425197, 0.40625, 'X[1] <= 109.5\ngini = 0.346\nsamples = 27\nvalue = [21, 6]'),
#  Text(0.04199475065616798, 0.34375, 'X[4] <= 34.0\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(0.031496062992125984, 0.28125, 'X[3] <= 40.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.02099737532808399, 0.21875, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0
 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4566929133858268, 0.59375, 'X[0] <= 5.5\ngini = 0.494\nsamples = 18\nvalue = [8, 10]'),
#  Text(0.4461942257217848, 0.53125, 'X[2] <= 70.0\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.4356955380577428, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4566929133858268, 0.46875, 'X[5] <= 46.9\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.4461942257217848, 0.40625, 'X[2] <= 75.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.4356955380577428, 0.34375, 'X[5] <= 30.9\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.4251968503937008, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4461942257217848, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4566929133858268, 0.34375, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.4671916010498688, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4671916010498688, 0.53125, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.5636482939632546, 0.65625, 'X[5] <= 29.3\ngini = 0.463\nsamples = 88\nvalue = [32, 56]'),
#  Text(0.5196850393700787, 0.59375, 'X[6] <= 1.379\ngini = 0.219\nsamples = 16\nvalue = [2, 14]'),
#  Text(0.5091863517060368, 0.53125, 'X[2] <= 62.0\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.49868766404199477, 0.46875, 'X[0] <= 5.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4881889763779528, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5091863517060368, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5196850393700787, 0.46875, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.5301837270341208, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6076115485564304, 0.59375, 'X[0] <= 7.5\ngini = 0.486\nsamples = 72\nvalue = [30, 42]'),
#  Text(0.5511811023622047, 0.53125, 'X[6] <= 0.262\ngini = 0.5\nsamples = 49\nvalue = [24, 25]'),
#  Text(0.5406824146981627, 0.46875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5616797900262467, 0.46875, 'X[6] <= 0.965\ngini = 0.498\nsamples = 45\nvalue = [24, 21]'),
#  Text(0.5328083989501312, 0.40625, 'X[2] <= 89.0\ngini = 0.475\nsamples = 36\nvalue = [22, 14]'),
#  Text(0.5223097112860893, 0.34375, 'X[0] <= 2.5\ngini = 0.492\nsamples = 32\nvalue = [18, 14]'),
#  Text(0.47506561679790027, 0.28125, 'X[2] <= 30.0\ngini = 0.473\nsamples = 13\nvalue = [5, 8]'),
#  Text(0.4645669291338583, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.48556430446194226, 0.21875, 'X[1] <= 101.0\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.47506561679790027, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.49606299212598426, 0.15625, 'X[1] <= 127.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.48556430446194226, 0.09375, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.5065616797900262, 0.09375, 'X[2] <= 84.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.49606299212598426, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5170603674540682, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5695538057742782, 0.28125, 'X[6] <= 0.515\ngini = 0.432\nsamples = 19\nvalue = [13, 6]'),
#  Text(0.5590551181102362, 0.21875, 'X[2] <= 65.0\ngini = 0.49\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.5485564304461942, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5695538057742782, 0.15625, 'X[7] <= 41.5\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.5485564304461942, 0.09375, 'X[1] <= 134.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.5380577427821522, 0.03125, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.5590551181102362, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5905511811023622, 0.09375, 'X[2] <= 83.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5800524934383202, 0.03125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6010498687664042, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5800524934383202, 0.21875, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5433070866141733, 0.34375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.5905511811023622, 0.40625, 'X[1] <= 107.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.5800524934383202, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6010498687664042, 0.34375, 'X[4] <= 191.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.5905511811023622, 0.28125, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6115485564304461, 0.28125, 'X[0] <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6010498687664042, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6220472440944882, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6640419947506562, 0.53125, 'X[6] <= 0.508\ngini = 0.386\nsamples = 23\nvalue = [6, 17]'),
#  Text(0.6535433070866141, 0.46875, 'X[6] <= 0.276\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.6325459317585301, 0.40625, 'X[5] <= 31.8\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6220472440944882, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6430446194225722, 0.34375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6745406824146981, 0.40625, 'X[5] <= 36.25\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.6640419947506562, 0.34375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6850393700787402, 0.34375, 'X[7] <= 47.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6745406824146981, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6955380577427821, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6745406824146981, 0.46875, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.8398950131233596, 0.90625, 'X[1] <= 155.5\ngini = 0.395\nsamples = 118\nvalue = [32, 86]'),
#  Text(0.7716535433070866, 0.84375, 'X[7] <= 41.0\ngini = 0.493\nsamples = 41\nvalue = [18, 23]'),
#  Text(0.7322834645669292, 0.78125, 'X[5] <= 41.65\ngini = 0.49\nsamples = 28\nvalue = [16, 12]'),
#  Text(0.7060367454068242, 0.71875, 'X[1] <= 146.5\ngini = 0.434\nsamples = 22\nvalue = [15, 7]'),
#  Text(0.6850393700787402, 0.65625, 'X[7] <= 28.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.6745406824146981, 0.59375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6955380577427821, 0.59375, 'X[3] <= 36.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.6850393700787402, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7060367454068242, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7270341207349081, 0.65625, 'X[6] <= 0.165\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.7165354330708661, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7375328083989501, 0.59375, 'X[1] <= 154.5\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.7270341207349081, 0.53125, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.7480314960629921, 0.53125, 'X[0] <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7375328083989501, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7585301837270341, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7585301837270341, 0.71875, 'X[1] <= 153.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.7480314960629921, 0.65625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7690288713910761, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8110236220472441, 0.78125, 'X[6] <= 0.251\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.800524934383202, 0.71875, 'X[7] <= 67.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.7900262467191601, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8110236220472441, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.821522309711286, 0.71875, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.9081364829396326, 0.84375, 'X[5] <= 29.85\ngini = 0.298\nsamples = 77\nvalue = [14, 63]'),
#  Text(0.8530183727034121, 0.78125, 'X[7] <= 28.0\ngini = 0.49\nsamples = 14\nvalue = [6, 8]'),
#  Text(0.84251968503937, 0.71875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.863517060367454, 0.71875, 'X[5] <= 26.65\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.8530183727034121, 0.65625, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8740157480314961, 0.65625, 'X[7] <= 36.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.863517060367454, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.884514435695538, 0.59375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.963254593175853, 0.78125, 'X[6] <= 2.233\ngini = 0.222\nsamples = 63\nvalue = [8, 55]'),
#  Text(0.952755905511811, 0.71875, 'X[5] <= 46.1\ngini = 0.2\nsamples = 62\nvalue = [7, 55]'),
#  Text(0.926509186351706, 0.65625, 'X[2] <= 93.0\ngini = 0.158\nsamples = 58\nvalue = [5, 53]'),
#  Text(0.905511811023622, 0.59375, 'X[6] <= 0.343\ngini = 0.109\nsamples = 52\nvalue = [3, 49]'),
#  Text(0.89501312335958, 0.53125, 'X[6] <= 0.27\ngini = 0.266\nsamples = 19\nvalue = [3, 16]'),
#  Text(0.884514435695538, 0.46875, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.905511811023622, 0.46875, 'X[3] <= 7.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.89501312335958, 0.40625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.916010498687664, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.916010498687664, 0.53125, 'gini = 0.0\nsamples = 33\nvalue = [0, 33]'),
#  Text(0.94750656167979, 0.59375, 'X[2] <= 99.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.937007874015748, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.958005249343832, 0.53125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.979002624671916, 0.65625, 'X[4] <= 177.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.968503937007874, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.989501312335958, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.973753280839895, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
dt_classifier=DecisionTreeClassifier(criterion="entropy",max_depth=3)
dt_classifier.fit(X_train,y_train)

score=dt_classifier.score(X_train,y_train)
print("R Squared Train : ",score)

score=dt_classifier.score(X_test,y_test)
print("R Squared Test : ",score)

y_pred=dt_classifier.predict(X_test)

mse=mean_squared_error(y_test,y_pred)
print("MSE:",mse)
print("RMSE:",mse**(1/2.0))
# Out:
# R Squared Train :  0.7653631284916201
# R Squared Test :  0.7359307359307359
# MSE: 0.26406926406926406
# RMSE: 0.513876701232177

# %%
from sklearn import tree
#from sklearn import plottree
plt.figure(figsize=(15,10))
tree.plot_tree(dt_classifier,filled=True,class_names=True)
plt.show()
